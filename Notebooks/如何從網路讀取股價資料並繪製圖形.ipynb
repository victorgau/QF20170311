# %% [markdown]
# # 如何從網路讀取股市資料並繪製圖形？

# %% [markdown]
# ## 匯入需要的模組

# %%
# %pylab inline

# Pandas v0.16 之前，使用下面這個
import pandas.io.data as web

# Pandas v0.16 之後，使用下面這個
# from pandas_datareader.data as web

from datetime import datetime
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## 讀取歷史資料

# %%
# 讀取從 1970/1/1 之後的股價資訊
df=web.DataReader("TSLA", 'yahoo', datetime(1970,1,1))

# %% [markdown]
# ## 檢視資料

# %%
df.tail()
# Out:
#                   Open        High         Low       Close   Volume  \
# Date
# 2016-07-14  223.119995  224.940002  221.050003  221.529999  2652900
# 2016-07-15  222.520004  222.750000  219.639999  220.399994  2213900
# 2016-07-18  219.639999  227.089996  218.300003  226.250000  3375200
# 2016-07-19  225.000000  229.100006  224.750000  225.259995  3030000
# 2016-07-20  226.470001  229.800003  225.000000  228.360001  2541600
#
#              Adj Close
# Date
# 2016-07-14  221.529999
# 2016-07-15  220.399994
# 2016-07-18  226.250000
# 2016-07-19  225.259995
# 2016-07-20  228.360001

# %% [markdown]
# ## 繪製圖形

# %%
df[['Close','Volume']].plot(subplots = True, figsize = (8, 8))
plt.legend(loc='best')
